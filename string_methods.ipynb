# %%
string="python"

# %% [markdown]
# # 1.string.capitalize()

# %%
#Converts the first letter of the string to uppercase and the rest to lowercase.


string="python"
string.capitalize()
# Out:
# 'Python'

# %% [markdown]
# # 2.string.lower()

# %%
#Converts all uppercase letters in a string to lowercase.

string="Python Developer"
string.lower()
# Out:
# 'python developer'

# %% [markdown]
# # 3.string.upper()

# %%
#Converts all lowercase letters in a string to uppercase.

string="python"
string.upper()
# Out:
# 'PYTHON'

# %% [markdown]
# # 4.string.title()

# %%
#Converts the first letter of each word to uppercase.

string="python developer"
string.title()
# Out:
# 'Python Developer'

# %% [markdown]
# # 5.string.swapcase()

# %%
#Changes uppercase letters to lowercase and lowercase to uppercase.

string="PYthon"
string.swapcase()
# Out:
# 'pyTHON'

# %% [markdown]
# # 6.string.casefold()

# %%
#Converts string to lowercase in a more aggressive way than lower() (used for comparisons).

string="PYTHOn"
string.casefold()
# Out:
# 'python'

# %% [markdown]
# # 7.string.center(width)

# %%
#Centers the string within the specified width.

string="python"
string.center(10)
# Out:
# '  python  '

# %% [markdown]
# # 8.string.ljust(width)

# %%
#Aligns the string to the left within given width.

string="python"
string.ljust(10)
# Out:
# 'python    '

# %% [markdown]
# # 9.string.rjust(width)

# %%
#Aligns the string to the right within given width.

string="python"
string.rjust(10)
# Out:
# '    python'

# %% [markdown]
# # 10.string.zfill(width)

# %%
#Adds zeros to the left of the string until the desired width is reached.

string="ram"
print(string.zfill(5))
# Out:
# 00ram

# %% [markdown]
# # 11.string.format(x)

# %%
#Formats strings using values.

name="arpit"
print("hello {}".format(name))
# Out:
# hello arpit

# %% [markdown]
# # 12.format_map(x)

# %%
#Formats string using a dictionary.


data = {"name": "Arpit"}
print("Hello {name}".format_map(data))
# Out:
# Hello Arpit

# %% [markdown]
# # 13.string.find(substring)

# %%
#Returns the index of the first occurrence of substring. Returns -1 if not found.

string="what is your name ?"
string.find("is")
# Out:
# 5

# %% [markdown]
# # 14.string.rfind(substring)

# %%
#Searches from the right side of the string.

text = "banana"
print(text.rfind("b"))
# Out:
# 0

# %% [markdown]
# # 15.string.index(substring)

# %%
#Same as find() but gives an error if substring is not found.

text = "banana"
print(text.index("a"))
# Out:
# 1

# %% [markdown]
# # 16.string.count(substring)

# %%
#Counts number of occurrences of substring.

text = "banana"
print(text.count("a"))
# Out:
# 3

# %% [markdown]
# # 17.string.startswith(prefix)

# %%
#Checks if string starts with given prefix.


string="python"
string.startswith("n")
# Out:
# False

# %% [markdown]
# # 18.string.endswith(suffix)

# %%
#Checks if string ends with given suffix.

string="python"
string.endswith("n")
# Out:
# True

# %% [markdown]
# # 19.string.isalnum()

# %%
#Returns True if string contains only letters and numbers.

string="#a1"
string.isalnum()
# Out:
# False

# %% [markdown]
# ## 20.string.isalpha()

# %%
#Returns True if string contains only letters.

string="#a1"
string.isalnum()
# Out:
# False

# %% [markdown]
# # 21.string.isdigit()

# %%
#Returns True if string contains only digits.

string="123"
string.isdigit()
# Out:
# True

# %% [markdown]
# # 22.string.isspace()

# %%
#Returns True if string contains only spaces.

string="123"
string.isspace()
# Out:
# False

# %% [markdown]
# # 23.string.islower()

# %%
#Checks if all letters are lowercase.

string="lower"
string.islower()
# Out:
# True

# %% [markdown]
# # 24.string.isupper()

# %%
#Checks if all letters are uppercase.

string="lower"
string.isupper()
# Out:
# False

# %% [markdown]
# # 25.string.istitle()

# %%
#Checks if string is in title case.

string="Hello"
string.istitle()
# Out:
# True

# %% [markdown]
# # 26.string.isidentifier()

# %%
#Checks if string is a valid variable name.

string="a1#"
string.isidentifier()
# Out:
# False

# %% [markdown]
# # 27.string.replace(old, new)

# %%
#Replaces old substring with new substring.

string="hello python"
string.replace("python","world")
# Out:
# 'hello world'

# %% [markdown]
# # 28.string.strip()

# %%
#Removes spaces from both beginning and end.

string="hello"
string.strip()
# Out:
# 'hello'

# %% [markdown]
# # 29.string.lstrip()

# %%
#Removes spaces from the left side.

string="   hello"
string.lstrip()
# Out:
# 'hello'

# %% [markdown]
# # 30.string.;rstrip()

# %%
#Removes spaces from the right side.

string="hello  "
string.rstrip()
# Out:
# 'hello'

# %% [markdown]
# # 31.string.removeprefix(prefix)

# %%
#Removes prefix if it exists.

text = "unhappy"
print(text.removeprefix("un"))
# Out:
# happy

# %% [markdown]
# # 31.string.removesuffix(suffix)

# %%
#Removes suffix if it exists.

text = "playing"
print(text.removesuffix("ing"))
# Out:
# play

# %% [markdown]
# # 32.string.split()

# %%
#Splits string into a list using separator.

text = "apple,banana,mango"
print(text.split(","))
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# # 33.string.rsplit()

# %%
#Splits string from right side.

text = "a-b-c"
print(text.rsplit("-", 1))
# Out:
# ['a-b', 'c']

# %% [markdown]
# # 34.string.splitlines()

# %%
#Splits string at line breaks.

text = "Hello\nWorld"
print(text.splitlines())
# Out:
# ['Hello', 'World']

# %% [markdown]
# # 35.join(iterable)

# %%
#Joins elements of list into a string.

words = ["Hello", "World"]
print(" ".join(words))
# Out:
# Hello World

# %% [markdown]
# # 36.string.encode()

# %%
#Converts string into bytes.

text = "123"
print(text.encode())
# Out:
# b'123'

# %% [markdown]
# # 37.string.translate()

# %%
#Replaces characters using translation table.

table = str.maketrans("a", "x")
print("apple".translate(table))
# Out:
# xpple

# %% [markdown]
# # 38.string.maketrans()

# %%
#Creates translation table for translate().

table = str.maketrans("a", "x")

# %% [markdown]
# # 39.string.len()

# %%
#Returns length of string.

text = "Python"
print(len(text))
# Out:
# 6

# %% [markdown]
# # 40.string.ord()

# %%
#Returns ASCII value of character.

print(ord("A"))
# Out:
# 65

# %% [markdown]
# # 41.string.chr()

# %%
#Returns character from ASCII value.

print(chr(65))
# Out:
# A

# %% [markdown]
# # 42.string.isascii()

# %%
#checks whether all characters in a string are ASCII characters (0–127).

string="python"
string.isascii()
# Out:
# True

# %% [markdown]
# # 43.string.expandtabs()

# %%
#Replaces tab spaces (\t) in a string with a specified number of spaces (default is 8 spaces).

text = "Hello\tWorld"
print(text.expandtabs(4))
# Out:
# Hello   World

# %% [markdown]
# # 44.string.partition()

# %%
#Splits the string into three parts:

#1.Part before separator
#2.Separator
#3.Part after separator

#Returns a tuple.

text = "apple-banana"
print(text.partition("-"))
# Out:
# ('apple', '-', 'banana')

# %% [markdown]
# # 45.string.isprintable()

# %%
#Checks whether all characters in the string are printable (letters, digits, symbols, spaces).

text = "Hello"
print(text.isprintable())   

text = "Hello\n"
print(text.isprintable())
# Out:
# True
# False
